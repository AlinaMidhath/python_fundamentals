# %% [markdown]
# <a href="https://colab.research.google.com/github/AlinaMidhath/python_fundamentals/blob/main/DS_15_11_24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns

# %%
df = pd.read_csv('Universities.csv')

# %%
df
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %%
plt.hist(df['SAT'])
# Out:
# (array([1., 3., 0., 0., 1., 2., 7., 4., 2., 5.]),
#  array([1005., 1046., 1087., 1128., 1169., 1210., 1251., 1292., 1333.,
#         1374., 1415.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['SAT'])
plt.show()

# %%
plt.hist(df['SAT'])
plt.xlabel()
# Out:
# (array([1., 3., 0., 0., 1., 2., 7., 4., 2., 5.]),
#  array([1005., 1046., 1087., 1128., 1169., 1210., 1251., 1292., 1333.,
#         1374., 1415.]),
#  <BarContainer object of 10 artists>)

# %%
sns.histplot(df['Accept'])
plt.show()

# %%
# prompt: Can you create a histogram on "Accept "column in dataframe df using seaborn library

sns.histplot(df['Accept'])
plt.xlabel('Accept')
plt.ylabel('Frequency')
plt.title('Histogram of Accept')
plt.show()

# %%
plt.plot(df['Accept'],df['SAT'])

# %%
plt.plot(df['Accept'],df['SAT'],'bo') #'go' green circles, 'bo' blue circles, 'r+' red plus signs
plt.xlabel('Accept')
plt.ylabel('SAT')
plt.title('Scatter plot ofAccept vs SAT')
plt.show()

# %%
# prompt: Create a scatter plot between accept column and sat column in dataframe df, and add pink color markers

plt.plot(df['Accept'], df['SAT'], 'mp')  # 'm.' for pink markers
plt.xlabel('Accept')
plt.ylabel('SAT')
plt.title('Scatter plot of Accept vs SAT')
plt.show()

# %%
help(plt.plot)
# Out:
# Help on function plot in module matplotlib.pyplot:
#
# plot(*args: 'float | ArrayLike | str', scalex: 'bool' = True, scaley: 'bool' = True, data=None, **kwargs) -> 'list[Line2D]'
#     Plot y versus x as lines and/or markers.
#
#     Call signatures::
#
#         plot([x], y, [fmt], *, data=None, **kwargs)
#         plot([x], y, [fmt], [x2], y2, [fmt2], ..., **kwargs)
#
#     The coordinates of the points or line nodes are given by *x*, *y*.
#
#     The optional parameter *fmt* is a convenient way for defining basic
#     formatting like color, marker and linestyle. It's a shortcut string
#     notation described in the *Notes* section below.
#
#     >>> plot(x, y)        # plot x and y using default line style and color
#     >>> plot(x, y, 'bo')  # plot x and y using blue circle markers
#     >>> plot(y)           # plot y using x as index array 0..N-1
#     >>> plot(y, 'r+')     # ditto, but with red plusses
#
#     You can use `.Line2D` properties as keyword arguments for more
# ...

# %%
sns.pairplot(df)

# %%
sns.pairplot(df.iloc[:,1:3])

# %%
sns.distplot(df['Accept'])
# Out:
# <ipython-input-27-6803a7d836ab>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Accept'])
# <Axes: xlabel='Accept', ylabel='Density'>

# %%
import warnings
warnings.filterwarnings('ignore')
sns.distplot(df['Accept'])
# Out:
# <Axes: xlabel='Accept', ylabel='Density'>

# %%
# prompt: Can you create distplot for all the columns in dataframe df

import matplotlib.pyplot as plt
import seaborn as sns

for column in df.columns:
  try:
    sns.distplot(df[column])
    plt.title(f'Distribution of {column}')
    plt.show()
  except Exception as e:
    print(f"Error creating distplot for {column}: {e}")
# Out:
# Error creating distplot for Univ: could not convert string to float: 'Brown'

# %%
plt.boxplot(df['Accept'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7879211d4b50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7879211d75b0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7879211d7040>],
#  'medians': [<matplotlib.lines.Line2D at 0x7879211d6140>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7879211d5bd0>],
#  'means': []}

# %%
# prompt: Can you Write a narrative summary on the boxplot of accept column in dataframe df

# Narrative Summary of the Boxplot of the 'Accept' Column

The boxplot of the 'Accept' column in the dataframe 'df' provides a visual summary of the distribution of acceptance rates across universities.

**Key Observations:**

* **Central Tendency:** The median acceptance rate, represented by the line within the box, appears to be around [estimate the median visually from the boxplot]. This suggests that a typical university in the dataset has an acceptance rate close to this value.

* **Spread and Variability:** The box itself, which encompasses the interquartile range (IQR), represents the middle 50% of acceptance rates. The length of the box indicates the degree of variability in the acceptance rates. A wider box implies greater spread and a larger range of acceptance rates within the dataset.

* **Outliers:** Any data points plotted beyond the whiskers as individual points are potential outliers. These are universities with acceptance rates significantly different from the rest of the dataset.  [Describe if you see any outliers, and their general location in relation to the box]. These outliers might represent either highly selective institutions with extremely low acceptance rates or universities with particularly high acceptance rates.

**Overall:**

The boxplot provides a concise way to visualize the distribution of acceptance rates. It shows the central tendency, spread, and any potential outliers within the data. The boxplot suggests [summarize your overall understanding of the acceptance rate based on the boxplot's characteristics].  For example, you might note that acceptance rates are generally clustered within a specific range but that there are some notably more or less selective institutions within the dataset.

# %%
# prompt: Can you create a boxplot on accept column of df dataframe

plt.boxplot(df['Accept'])
plt.xlabel('Accept')
plt.ylabel('Values')
plt.title('Boxplot of Accept')
plt.show()

# %% [markdown]
# NUMPY

# %%
import numpy as np

# %%
a=np.array([1,2,3,4])

# %%
type(a)
# Out:
# numpy.ndarray

# %%
a.shape
# Out:
# (4,)

# %%
a.size
# Out:
# 4

# %%
a.sum()
# Out:
# 10

# %%
a.prod()
# Out:
# 24

# %%
a.min()
# Out:
# 1

# %%
a.max()
# Out:
# 4

# %%
b = np.array([[1,2,3,4],[5,6,7,8]])

# %%
b
# Out:
# array([[1, 2, 3, 4],
#        [5, 6, 7, 8]])

# %%
type(b)
# Out:
# numpy.ndarray

# %%
b.shape
# Out:
# (2, 4)

# %%
b.size
# Out:
# 8

# %%
b=b.reshape(4,2)

# %%
b
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6],
#        [7, 8]])

# %%
b[0]
# Out:
# array([1, 2])

# %%
b[0,0]
# Out:
# 1

# %%
b[0,1]
# Out:
# 2

# %%
#b[0,2] # error bcs we dont have three cols in our array b

# %%
b.sum(axis =0)
# Out:
# array([16, 20])

# %%
b.sum(axis =1)
# Out:
# array([ 3,  7, 11, 15])
